# %% [markdown]
# # CIFAR-10 FCN
# The goal of this model is to use CIFAR-10 to solve image classification problems.
# This model uses Fully Convolutional Networks (FCN).

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import keras
from keras import layers
from tensorflow.keras.datasets import cifar10

import numpy as np
import matplotlib.pyplot as plt

from keras import backend as K
print(K.backend())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774613481.473185    5651 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tensorflow

# %%
from keras.layers import Input, Flatten, Dense

model = keras.models.Sequential([
    Input(shape=(32, 32, 3)),
    Flatten(),
    Dense(32, activation="relu"),
    Dense(1, activation="softmax")
])

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

print(x_train.shape)
print(y_train.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 1)

# %%
model.compile(
    loss=keras.losses.SparseCategoricalCrossentropy(),
    optimizer=keras.optimizers.Adam(),
    metrics=["accuracy"],
)

# %%
history = model.fit(x_train, y_train, batch_size=16, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# /home/juhana/anaconda3_v2/envs/keras/lib/python3.11/site-packages/keras/src/ops/nn.py:947: UserWarning: You are using a softmax over axis -1 of a tensor of shape (64, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# I0000 00:00:1774614188.753498    5712 service.cc:153] XLA service 0x72e89c030610 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1774614188.753531    5712 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6 (Driver: 12.8.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.20.0)
# I0000 00:00:1774614188.798360    5712 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1774614188.906222    5712 cuda_dnn.cc:461] Loaded cuDNN version 92000
# I0000 00:00:1774614188.921805    5712 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1151__.11
#  77/625 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.1016 - loss: nan
# I0000 00:00:1774614190.395307    5712 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 619/625 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.0983 - loss: nan
# /home/juhana/anaconda3_v2/envs/keras/lib/python3.11/site-packages/keras/src/ops/nn.py:947: UserWarning: You are using a softmax over axis -1 of a tensor of shape (None, 1). This axis has size 1. The softmax operation will always return the value 1, which is likely not what you intended. Did you mean to use a sigmoid instead?
#   warnings.warn(
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.0996 - loss: nan - val_accuracy: 0.1014 - val_loss: nan
# Epoch 2/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1014 - val_loss: nan
# Epoch 3/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1014 - val_loss: nan
# Epoch 4/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1014 - val_loss: nan
# Epoch 5/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1014 - val_loss: nan
# Epoch 6/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1014 - val_loss: nan
# Epoch 7/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1014 - val_loss: nan
# Epoch 8/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1014 - val_loss: nan
# Epoch 9/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1014 - val_loss: nan
# Epoch 10/10
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.0997 - loss: nan - val_accuracy: 0.1014 - val_loss: nan

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.grid()
plt.show()

# %%
x = x_test
y = model(x)
start = 2000

for k in range(10):
    plt.figure(figsize=(8, 2))
    plt.subplot(1,2,1)
    plt.imshow(x[start+k].reshape((28, 28)), cmap='gray')
    ind = np.arange(0, 10)
    plt.subplot(1,2,2)
    plt.bar(ind, y[start+k].numpy().flatten())
    plt.xticks(range(10))
