# %% [markdown]
# # CIFAR-10 FCN
# The goal of this model is to use CIFAR-10 to solve image classification problems.
# This model uses Fully Convolutional Networks (FCN).

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import keras
from keras import layers
from tensorflow.keras.datasets import cifar10

import numpy as np
import matplotlib.pyplot as plt

from keras import backend as K
print(K.backend())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774615370.973270   12455 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tensorflow

# %%
from keras.layers import Input, Flatten, Dense

model = keras.models.Sequential([
    Input(shape=(32, 32, 3)),
    Flatten(),
    Dense(256, activation="relu"),
    Dense(256, activation="relu"),
    Dense(128, activation="relu"),
    Dense(10, activation="softmax")
])
# Out:
# I0000 00:00:1774615373.422436   12455 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1767 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
from tensorflow.keras.utils import to_categorical
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

x_train, x_test = x_train / 255, x_test / 255

print(x_train.shape)
print(y_train.shape)
# Out:
# (50000, 32, 32, 3)
# (50000, 10)

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(),
    metrics=["accuracy"],
)

# %%
history = model.fit(x_train, y_train, batch_size=32, epochs=10, validation_split=0.2)
# Out:
# W0000 00:00:1774615476.626166   12455 cpu_allocator_impl.cc:82] Allocation of 491520000 exceeds 10% of free system memory.
# W0000 00:00:1774615477.569954   12455 cpu_allocator_impl.cc:82] Allocation of 491520000 exceeds 10% of free system memory.
# Epoch 1/15
# I0000 00:00:1774615478.620763   12512 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_97009__.17
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.1628 - loss: 2.1431 - val_accuracy: 0.1795 - val_loss: 2.1006
# Epoch 2/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1868 - loss: 2.0678 - val_accuracy: 0.1886 - val_loss: 2.0656
# Epoch 3/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1917 - loss: 2.0580 - val_accuracy: 0.1888 - val_loss: 2.0600
# Epoch 4/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1922 - loss: 2.0571 - val_accuracy: 0.1944 - val_loss: 2.0576
# Epoch 5/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1902 - loss: 2.0534 - val_accuracy: 0.1898 - val_loss: 2.0673
# Epoch 6/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1928 - loss: 2.0509 - val_accuracy: 0.1913 - val_loss: 2.0556
# Epoch 7/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1931 - loss: 2.0475 - val_accuracy: 0.1912 - val_loss: 2.0534
# Epoch 8/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1951 - loss: 2.0459 - val_accuracy: 0.1896 - val_loss: 2.0755
# Epoch 9/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.1926 - loss: 2.0462 - val_accuracy: 0.1912 - val_loss: 2.0531
# Epoch 10/15
# 1250/1250 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.1938 - loss: 2.0453 - val_accuracy: 0.1928 - val_loss: 2.0523
# Epoch 11/15
#  297/1250 ━━━━━━━━━━━━━━━━━━━━ 1:09 73ms/step - accuracy: 0.2010 - loss: 2.0356

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.grid()
plt.show()

# %%
x = x_test
y = model(x)
start = 2000

for k in range(10):
    plt.figure(figsize=(8, 2))
    plt.subplot(1,2,1)
    plt.imshow(x[start+k].reshape((28, 28)), cmap='gray')
    ind = np.arange(0, 10)
    plt.subplot(1,2,2)
    plt.bar(ind, y[start+k].numpy().flatten())
    plt.xticks(range(10))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 8
#       6 plt.figure(figsize=(8, 2))
#       7 plt.subplot(1,2,1)
# ----> 8 plt.imshow(x[start+k].reshape((28, 28)), cmap='gray')
#       9 ind = np.arange(0, 10)
#      10 plt.subplot(1,2,2)
#
# ValueError: cannot reshape array of size 3072 into shape (28,28)
