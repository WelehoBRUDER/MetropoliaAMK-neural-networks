# %% [markdown]
# # Assignment 2
# This fully connected neural network predicts the median house value in California districts.

# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.models import Sequential
from keras.layers import Input, Dense
from keras.datasets import california_housing

(inputs, targets), (x_test, y_test) = california_housing.load_data(version='large', 
                                        test_split=0.2)
print(inputs.shape, targets.shape)
print(x_test.shape, y_test.shape)
# Out:
# C:\Users\Omistaja\anaconda3\envs\keras\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# (16512, 8) (16512,)
# (4128, 8) (4128,)

# %%
import math
# Get 80% of all inputs, since targets is the same size this also applies to it
split = math.floor(inputs.shape[0] * 0.8)
x_train = inputs[:split]
y_train = targets[:split]
x_val = inputs[split:]
y_val = targets[split:]

# %%
mean = x_train.mean(axis=0) # mean and standard deviation computed from training set only
std = x_train.std(axis=0)
x_train -= mean
x_train /= std
x_test -= mean
x_test /= std
x_val -= mean
x_val /= std
y_train /= 1e5
y_test /= 1e5
y_val /= 1e5

# %%
# define variables for reuse in other models
n_epochs = 100
n_batch = 32
neurons1_n = 128
neurons2_n = 64

# define the model architecture
model = Sequential([
    Input(shape=(8,)),
    Dense(neurons1_n, activation='relu'),
    Dense(neurons2_n, activation='relu'),
    Dense(1)
    ])

# configure the learning algorithm
model.compile(optimizer='adam',loss='mse',metrics=['mae'])
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(x_train, y_train, epochs=n_epochs, batch_size=n_batch, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 935us/step - loss: 0.7166 - mae: 0.5763 - val_loss: 0.4082 - val_mae: 0.4547
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - loss: 0.3808 - mae: 0.4393 - val_loss: 0.3858 - val_mae: 0.4336
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 0.3543 - mae: 0.4221 - val_loss: 0.3756 - val_mae: 0.4274
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 0.3403 - mae: 0.4114 - val_loss: 0.3439 - val_mae: 0.4084
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.3296 - mae: 0.4040 - val_loss: 0.3330 - val_mae: 0.4043
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - loss: 0.3186 - mae: 0.3973 - val_loss: 0.3278 - val_mae: 0.3878
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - loss: 0.3091 - mae: 0.3870 - val_loss: 0.3294 - val_mae: 0.4029
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - loss: 0.3033 - mae: 0.3835 - val_loss: 0.3407 - val_mae: 0.4062
# ...

# %%
plt.plot(history.history['mae'][10:], label='train MAE')
plt.plot(history.history['val_mae'][10:], label='val MAE')
plt.legend() 
plt.title("128x64 layers")
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')
# Out:
# Text(0, 0.5, 'Mean absolute error (in 100000 $)')

# %%
# Try slightly smaller
neurons1_n = 64
neurons2_n = 64

# define the model architecture
model = Sequential([
    Input(shape=(8,)),
    Dense(neurons1_n, activation='relu'),
    Dense(neurons2_n, activation='relu'),
    Dense(1)
    ])

# configure the learning algorithm
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
history = model.fit(x_train, y_train, epochs=n_epochs, batch_size=n_batch, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 915us/step - loss: 0.8041 - mae: 0.6210 - val_loss: 0.4134 - val_mae: 0.4745
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 0.3910 - mae: 0.4490 - val_loss: 0.3797 - val_mae: 0.4346
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.3660 - mae: 0.4312 - val_loss: 0.3689 - val_mae: 0.4330
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - loss: 0.3509 - mae: 0.4217 - val_loss: 0.3668 - val_mae: 0.4401
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 0.3401 - mae: 0.4140 - val_loss: 0.3533 - val_mae: 0.4100
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - loss: 0.3287 - mae: 0.4043 - val_loss: 0.3357 - val_mae: 0.3991
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step - loss: 0.3229 - mae: 0.3997 - val_loss: 0.3492 - val_mae: 0.4183
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - loss: 0.3155 - mae: 0.3954 - val_loss: 0.3233 - val_mae: 0.3966
# ...

# %%
plt.plot(history.history['mae'][10:], label='train MAE')
plt.plot(history.history['val_mae'][10:], label='val MAE')
plt.legend() 
plt.title("64x64 layers")
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')
# Out:
# Text(0, 0.5, 'Mean absolute error (in 100000 $)')

# %% [markdown]
# The 64x64 model still shows clear overfitting, but it produces a slightly more balanced result.
# Next, a few different regularization methods will be used to handle the overfitting.

# %% [markdown]
# ## Early stopping

# %%
# First trying early stopping
# define the model architecture
model = Sequential([
    Input(shape=(8,)),
    Dense(neurons1_n, activation='relu'),
    Dense(neurons2_n, activation='relu'),
    Dense(1)
    ])

# configure the learning algorithm
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(x_train, y_train, epochs=n_epochs, batch_size=n_batch, validation_data=(x_val, y_val), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 927us/step - loss: 0.7541 - mae: 0.6005 - val_loss: 0.4091 - val_mae: 0.4528
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - loss: 0.3911 - mae: 0.4464 - val_loss: 0.3822 - val_mae: 0.4367
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - loss: 0.3631 - mae: 0.4288 - val_loss: 0.3689 - val_mae: 0.4172
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 0.3534 - mae: 0.4216 - val_loss: 0.3534 - val_mae: 0.4106
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - loss: 0.3365 - mae: 0.4100 - val_loss: 0.3466 - val_mae: 0.3998
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - loss: 0.3260 - mae: 0.4014 - val_loss: 0.3442 - val_mae: 0.4020
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - loss: 0.3189 - mae: 0.3956 - val_loss: 0.3419 - val_mae: 0.4027
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - loss: 0.3121 - mae: 0.3909 - val_loss: 0.3274 - val_mae: 0.3966
# ...

# %%
plt.plot(history.history['mae'], label='train MAE')
plt.plot(history.history['val_mae'], label='val MAE')
plt.legend()
plt.title("Early stopping (patience=10)")
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')
# Out:
# Text(0, 0.5, 'Mean absolute error (in 100000 $)')

# %%
# Regularization
from keras.regularizers import l2

model = Sequential([
    Input(shape=(8,)),
    Dense(neurons1_n, activation='relu', kernel_regularizer=l2(0.001)),
    Dense(neurons2_n, activation='relu', kernel_regularizer=l2(0.001)),
    Dense(1)
])
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
history = model.fit(x_train, y_train, epochs=n_epochs, batch_size=n_batch, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 901us/step - loss: 0.9168 - mae: 0.6230 - val_loss: 0.4808 - val_mae: 0.4535
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 774us/step - loss: 0.4611 - mae: 0.4487 - val_loss: 0.4509 - val_mae: 0.4487
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - loss: 0.4301 - mae: 0.4332 - val_loss: 0.4296 - val_mae: 0.4242
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.4104 - mae: 0.4241 - val_loss: 0.4333 - val_mae: 0.4188
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.4005 - mae: 0.4185 - val_loss: 0.4109 - val_mae: 0.4234
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step - loss: 0.3856 - mae: 0.4106 - val_loss: 0.3886 - val_mae: 0.4020
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - loss: 0.3753 - mae: 0.4045 - val_loss: 0.4015 - val_mae: 0.4197
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - loss: 0.3639 - mae: 0.3964 - val_loss: 0.3819 - val_mae: 0.3939
# ...

# %%
plt.plot(history.history['mae'], label='train MAE')
plt.plot(history.history['val_mae'], label='val MAE')
plt.legend()
plt.title("L2 Regularizer (0.001)")
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')
# Out:
# Text(0, 0.5, 'Mean absolute error (in 100000 $)')

# %%
from keras.layers import Dropout

model = Sequential([
    Input(shape=(8,)),
    Dense(neurons1_n, activation='relu'),
    Dropout(0.2),
    Dense(neurons2_n, activation='relu'),
    Dropout(0.1),
    Dense(1)
    ])

# configure the learning algorithm
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
history = model.fit(x_train, y_train, epochs=n_epochs, batch_size=n_batch, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 939us/step - loss: 0.9932 - mae: 0.6991 - val_loss: 0.4457 - val_mae: 0.4789
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 823us/step - loss: 0.5088 - mae: 0.5121 - val_loss: 0.4029 - val_mae: 0.4461
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - loss: 0.4625 - mae: 0.4863 - val_loss: 0.3877 - val_mae: 0.4338
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - loss: 0.4321 - mae: 0.4705 - val_loss: 0.3699 - val_mae: 0.4240
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - loss: 0.4241 - mae: 0.4644 - val_loss: 0.3770 - val_mae: 0.4202
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 859us/step - loss: 0.4072 - mae: 0.4529 - val_loss: 0.3614 - val_mae: 0.4257
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - loss: 0.3948 - mae: 0.4462 - val_loss: 0.3528 - val_mae: 0.4064
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - loss: 0.3846 - mae: 0.4381 - val_loss: 0.3535 - val_mae: 0.4063
# ...

# %%
plt.plot(history.history['mae'], label='train MAE')
plt.plot(history.history['val_mae'], label='val MAE')
plt.legend()
plt.title("Dropout")
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')
# Out:
# Text(0, 0.5, 'Mean absolute error (in 100000 $)')

# %%
from keras.layers import BatchNormalization
model = Sequential([
    Input(shape=(8,)),
    Dense(neurons1_n, activation='relu'),
    BatchNormalization(),
    Dense(neurons2_n, activation='relu'),
    BatchNormalization(),
    Dense(1)
    ])

# configure the learning algorithm
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
history = model.fit(x_train, y_train, epochs=n_epochs, batch_size=n_batch, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.2005 - mae: 0.8037 - val_loss: 0.4179 - val_mae: 0.4600
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 888us/step - loss: 0.4349 - mae: 0.4876 - val_loss: 0.3632 - val_mae: 0.4154
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 911us/step - loss: 0.4086 - mae: 0.4658 - val_loss: 0.3691 - val_mae: 0.4222
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 898us/step - loss: 0.3917 - mae: 0.4542 - val_loss: 0.3461 - val_mae: 0.4187
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 894us/step - loss: 0.3775 - mae: 0.4437 - val_loss: 0.3419 - val_mae: 0.4064
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 907us/step - loss: 0.3808 - mae: 0.4508 - val_loss: 0.3372 - val_mae: 0.4001
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 879us/step - loss: 0.3652 - mae: 0.4358 - val_loss: 0.3379 - val_mae: 0.4111
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 0.3577 - mae: 0.4318 - val_loss: 0.3222 - val_mae: 0.3957
# ...

# %%
plt.plot(history.history['mae'], label='train MAE')
plt.plot(history.history['val_mae'], label='val MAE')
plt.legend()
plt.title("Batch normalization")
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')
# Out:
# Text(0, 0.5, 'Mean absolute error (in 100000 $)')

# %% [markdown]
# The most promising methods seem to be dropout and batch normalization.
# The final model will use both methods, and also implement early stopping to find the optimal epochs.

# %% [markdown]
# ## Finalized model

# %%
model = Sequential([
    Input(shape=(8,)),
    Dense(neurons1_n, activation='relu'),
    Dropout(0.2),
    BatchNormalization(),
    Dense(neurons2_n, activation='relu'),
    BatchNormalization(),
    Dropout(0.1),
    Dense(1)
    ])

# configure the learning algorithm
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = model.fit(x_train, y_train, epochs=n_epochs, batch_size=n_batch, validation_data=(x_val, y_val), callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - loss: 1.7425 - mae: 0.9893 - val_loss: 0.5170 - val_mae: 0.5474
# Epoch 2/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.6906 - mae: 0.6260 - val_loss: 0.3966 - val_mae: 0.4552
# Epoch 3/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5827 - mae: 0.5727 - val_loss: 0.3656 - val_mae: 0.4281
# Epoch 4/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.5185 - mae: 0.5353 - val_loss: 0.3938 - val_mae: 0.4497
# Epoch 5/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4871 - mae: 0.5176 - val_loss: 0.3448 - val_mae: 0.4176
# Epoch 6/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4604 - mae: 0.5013 - val_loss: 0.3593 - val_mae: 0.4315
# Epoch 7/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.4547 - mae: 0.4941 - val_loss: 0.3415 - val_mae: 0.4206
# Epoch 8/100
# 413/413 ━━━━━━━━━━━━━━━━━━━━ 0s 981us/step - loss: 0.4371 - mae: 0.4850 - val_loss: 0.3400 - val_mae: 0.4167
# Epoch 9/100
# ...

# %%
plt.plot(history.history['mae'], label='train MAE')
plt.plot(history.history['val_mae'], label='val MAE')
plt.legend()
plt.title("Finalized model")
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')
# Out:
# Text(0, 0.5, 'Mean absolute error (in 100000 $)')
