# %% [markdown]
# # Assignment 2
# This fully connected neural network predicts the median house value in California districts.

# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.models import Sequential
from keras.layers import Input, Dense
from keras.datasets import california_housing

(inputs, targets), (x_test, y_test) = california_housing.load_data(version='large', 
                                        test_split=0.2)
print(inputs.shape, targets.shape)
print(x_test.shape, y_test.shape)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774867120.316387   27100 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# (16512, 8) (16512,)
# (4128, 8) (4128,)

# %%
import math
# Get 80% of all inputs, since targets is the same size this also applies to it
split = math.floor(inputs.shape[0] * 0.8)
x_train = inputs[:split]
y_train = targets[:split]
x_val = inputs[split:]
y_val = targets[split:]

# %%
mean = x_train.mean(axis=0) # mean and standard deviation computed from training set only
std = x_train.std(axis=0)
x_train -= mean
x_train /= std
x_test -= mean
x_test /= std
x_val -= mean
x_val /= std
y_train /= 1e5
y_test /= 1e5
y_val /= 1e5

# %%
# define the model architecture
model = Sequential([
    Input(shape=(8,)),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(256, activation='relu'),
    Dense(1)
    ])

# configure the learning algorithm
model.compile(optimizer='adam',loss='mse',metrics=['mae'])
# Out:
# I0000 00:00:1774867124.395954   27100 gpu_device.cc:2043] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1767 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
history = model.fit(x_train, y_train, epochs=200, batch_size=64, validation_data=(x_val, y_val), verbose=0)
# Out:
# I0000 00:00:1774867127.547803   27163 service.cc:153] XLA service 0x7dab88033b00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1774867127.547875   27163 service.cc:161]   StreamExecutor [0]: NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6 (Driver: 12.8.0; Runtime: 12.9.0; Toolkit: 12.5.0; DNN: 9.20.0)
# I0000 00:00:1774867127.591452   27163 dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1774867127.862379   27163 cuda_dnn.cc:461] Loaded cuDNN version 92000
# I0000 00:00:1774867127.877288   27163 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1568__.10
# I0000 00:00:1774867130.462265   27235 subprocess_compilation.cc:348] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_MatMul_28', 4 bytes spill stores, 4 bytes spill loads
#
# I0000 00:00:1774867133.523715   27163 device_compiler.h:208] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# I0000 00:00:1774867134.797768   27162 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_1568__.10

# %%
plt.plot(history.history['loss'][10:], label='train loss')
plt.plot(history.history['val_loss'][10:], label='val loss')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
plt.plot(history.history['mae'][10:], label='train MAE')
plt.plot(history.history['val_mae'][10:], label='val MAE')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')
# Out:
# Text(0, 0.5, 'Mean absolute error (in 100000 $)')

# %%
# First trying early stopping
# define the model architecture
model = Sequential([
    Input(shape=(8,)),
    Dense(512, activation='relu'),
    Dense(256, activation='relu'),
    Dense(256, activation='relu'),
    Dense(1)
    ])

# configure the learning algorithm
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=10)
history = model.fit(x_train, y_train, epochs=200, batch_size=64, validation_data=(x_val, y_val), callbacks=[early_stopping])
# Out:
# Epoch 1/200
# I0000 00:00:1774867480.782011   27164 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_215387__.10
#  82/207 ━━━━━━━━━━━━━━━━━━━━ 40s 326ms/step - loss: 1.7397 - mae: 0.9386
# I0000 00:00:1774867483.870533   27164 dot_merger.cc:481] Merging Dots in computation: a_inference_one_step_on_data_215387__.10
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 8s 21ms/step - loss: 0.6300 - mae: 0.5484 - val_loss: 0.4066 - val_mae: 0.4314
# Epoch 2/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3664 - mae: 0.4296 - val_loss: 0.3644 - val_mae: 0.4114
# Epoch 3/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3387 - mae: 0.4096 - val_loss: 0.3503 - val_mae: 0.4157
# Epoch 4/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3254 - mae: 0.4004 - val_loss: 0.3439 - val_mae: 0.4027
# Epoch 5/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.3133 - mae: 0.3903 - val_loss: 0.3221 - val_mae: 0.3872
# Epoch 6/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2993 - mae: 0.3799 - val_loss: 0.3490 - val_mae: 0.3998
# Epoch 7/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.3001 - mae: 0.3804 - val_loss: 0.3093 - val_mae: 0.3738
# Epoch 8/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2954 - mae: 0.3763 - val_loss: 0.3004 - val_mae: 0.3710
# Epoch 9/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2873 - mae: 0.3698 - val_loss: 0.3466 - val_mae: 0.3950
# Epoch 10/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2946 - mae: 0.3749 - val_loss: 0.3019 - val_mae: 0.3653
# Epoch 11/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2755 - mae: 0.3615 - val_loss: 0.3056 - val_mae: 0.3717
# Epoch 12/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2815 - mae: 0.3655 - val_loss: 0.3104 - val_mae: 0.3859
# Epoch 13/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2752 - mae: 0.3616 - val_loss: 0.3026 - val_mae: 0.3685
# Epoch 14/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2702 - mae: 0.3574 - val_loss: 0.3388 - val_mae: 0.4179
# Epoch 15/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2698 - mae: 0.3570 - val_loss: 0.2936 - val_mae: 0.3509
# Epoch 16/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 27s 133ms/step - loss: 0.2615 - mae: 0.3516 - val_loss: 0.2893 - val_mae: 0.3660
# Epoch 17/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2619 - mae: 0.3518 - val_loss: 0.3204 - val_mae: 0.3636
# Epoch 18/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2574 - mae: 0.3472 - val_loss: 0.2981 - val_mae: 0.3522
# Epoch 19/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2585 - mae: 0.3496 - val_loss: 0.3059 - val_mae: 0.3573
# Epoch 20/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2542 - mae: 0.3451 - val_loss: 0.2862 - val_mae: 0.3550
# Epoch 21/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2529 - mae: 0.3443 - val_loss: 0.3041 - val_mae: 0.3825
# Epoch 22/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2500 - mae: 0.3430 - val_loss: 0.3024 - val_mae: 0.3602
# Epoch 23/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2456 - mae: 0.3389 - val_loss: 0.2855 - val_mae: 0.3599
# Epoch 24/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2451 - mae: 0.3394 - val_loss: 0.2993 - val_mae: 0.3742
# Epoch 25/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2460 - mae: 0.3393 - val_loss: 0.3031 - val_mae: 0.3552
# Epoch 26/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ -24s 7ms/step - loss: 0.2445 - mae: 0.3393 - val_loss: 0.2920 - val_mae: 0.3533
# Epoch 27/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2342 - mae: 0.3314 - val_loss: 0.2822 - val_mae: 0.3439
# Epoch 28/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2321 - mae: 0.3291 - val_loss: 0.2859 - val_mae: 0.3669
# Epoch 29/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2338 - mae: 0.3323 - val_loss: 0.2703 - val_mae: 0.3399
# Epoch 30/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.2321 - mae: 0.3315 - val_loss: 0.2758 - val_mae: 0.3437
# Epoch 31/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2262 - mae: 0.3249 - val_loss: 0.2725 - val_mae: 0.3451
# Epoch 32/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2251 - mae: 0.3250 - val_loss: 0.3025 - val_mae: 0.3755
# Epoch 33/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2230 - mae: 0.3244 - val_loss: 0.2635 - val_mae: 0.3336
# Epoch 34/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2218 - mae: 0.3239 - val_loss: 0.2873 - val_mae: 0.3419
# Epoch 35/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2166 - mae: 0.3187 - val_loss: 0.2827 - val_mae: 0.3581
# Epoch 36/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2164 - mae: 0.3181 - val_loss: 0.2763 - val_mae: 0.3617
# Epoch 37/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2168 - mae: 0.3185 - val_loss: 0.2906 - val_mae: 0.3606
# Epoch 38/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2105 - mae: 0.3144 - val_loss: 0.2779 - val_mae: 0.3489
# Epoch 39/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2098 - mae: 0.3129 - val_loss: 0.2761 - val_mae: 0.3414
# Epoch 40/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2030 - mae: 0.3069 - val_loss: 0.3013 - val_mae: 0.3877
# Epoch 41/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2057 - mae: 0.3101 - val_loss: 0.2837 - val_mae: 0.3653
# Epoch 42/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2007 - mae: 0.3070 - val_loss: 0.2881 - val_mae: 0.3554
# Epoch 43/200
# 207/207 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2048 - mae: 0.3100 - val_loss: 0.2719 - val_mae: 0.3351

# %%
plt.plot(history.history['mae'][10:], label='train MAE')
plt.plot(history.history['val_mae'][10:], label='val MAE')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')
# Out:
# Text(0, 0.5, 'Mean absolute error (in 100000 $)')

# %%
# Regularization
from keras.regularizers import l2

model = Sequential([
    Input(shape=(8,)),
    Dense(512, activation='relu', kernel_regularizer=l2(0.01)),
    Dense(256, activation='relu', kernel_regularizer=l2(0.01)),
    Dense(256, activation='relu', kernel_regularizer=l2(0.01)),
    Dense(1)
])
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
history = model.fit(x_train, y_train, epochs=200, batch_size=64, validation_data=(x_val, y_val), verbose=0)

# %%
plt.plot(history.history['mae'][10:], label='train MAE')
plt.plot(history.history['val_mae'][10:], label='val MAE')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')

# %%
from keras.layers import Dropout
model = Sequential([
    Input(shape=(8,)),
    Dense(512, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(256, activation='relu'),
    Dropout(0.2),
    Dense(1)
    ])

# configure the learning algorithm
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
history = model.fit(x_train, y_train, epochs=200, batch_size=64, validation_data=(x_val, y_val), verbose=0)

# %%
plt.plot(history.history['mae'][10:], label='train MAE')
plt.plot(history.history['val_mae'][10:], label='val MAE')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')

# %%
from keras.layers import BatchNormalization
model = Sequential([
    Input(shape=(8,)),
    Dense(512, activation='relu'),
    BatchNormalization(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dense(1)
    ])

# configure the learning algorithm
model.compile(optimizer='adam',loss='mse',metrics=['mae'])

# %%
history = model.fit(x_train, y_train, epochs=200, batch_size=64, validation_data=(x_val, y_val), verbose=0)

# %%
plt.plot(history.history['mae'][10:], label='train MAE')
plt.plot(history.history['val_mae'][10:], label='val MAE')
plt.legend()
plt.xlabel('Epoch')
plt.ylabel('Mean absolute error (in 100000 $)')
