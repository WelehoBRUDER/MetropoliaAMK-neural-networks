# %% [markdown]
# # CIFAR-10 CNN

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import keras
from keras import layers
from tensorflow.keras.datasets import cifar10

import numpy as np
import matplotlib.pyplot as plt

from keras import backend as K
print(K.backend())
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774617485.992852   23061 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tensorflow

# %%
from tensorflow.keras.utils import to_categorical
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

x_train, x_test = x_train / 255, x_test / 255
x_train = np.expand_dims(x_train, -1)
x_test = np.expand_dims(x_test, -1)

print(x_train.shape)
print(y_train.shape)
# Out:
# /home/juhana/anaconda3_v2/envs/keras/lib/python3.11/site-packages/keras/src/datasets/cifar.py:18: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   d = cPickle.load(f, encoding="bytes")
# (50000, 32, 32, 3, 1)
# (50000, 10)

# %%
from keras.layers import Input, Flatten, Dense
from keras import models

inputs = keras.Input(shape=(32, 32, 3))
x = keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu')(inputs)
x = keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
x = keras.layers.Conv2D(64, kernel_size=(3, 3), activation='relu')(x)
x = keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
x = layers.Flatten()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(10, activation="softmax")(x)

model = keras.Model(inputs=inputs, outputs=outputs, name="mnist_model")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       1 from keras.layers import Input, Flatten, Dense
#       2 from keras import models
# ----> 4 inputs = keras.Input(shape=input_shape)
#       5 x = keras.layers.Conv2D(32, kernel_size=(3, 3), activation='relu')(inputs)
#       6 x = keras.layers.MaxPooling2D(pool_size=(2, 2))(x)
#
# NameError: name 'input_shape' is not defined

# %%
model.compile(
    loss="categorical_crossentropy",
    optimizer=keras.optimizers.Adam(),
    metrics=["accuracy"],
)

# %%
history = model.fit(x_train, y_train, batch_size=32, epochs=10, validation_split=0.2)
# Out:
# W0000 00:00:1774617492.417840   23061 cpu_allocator_impl.cc:82] Allocation of 491520000 exceeds 10% of free system memory.
# W0000 00:00:1774617493.121423   23061 cpu_allocator_impl.cc:82] Allocation of 491520000 exceeds 10% of free system memory.
# Epoch 1/10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 history = model.fit(x_train, y_train, batch_size=32, epochs=10, validation_split=0.2)
#
# File ~/anaconda3_v2/envs/keras/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~/anaconda3_v2/envs/keras/lib/python3.11/site-packages/keras/src/backend/tensorflow/nn.py:1159, in categorical_crossentropy(target, output, from_logits, axis)
#    1153     raise ValueError(
#    1154         "Arguments `target` and `output` must be at least rank 1. "
#    1155         "Received: "
#    1156         f"target.shape={target.shape}, output.shape={output.shape}"
#    1157     )
#    1158 if len(target.shape) != len(output.shape):
# -> 1159     raise ValueError(
#    1160         "Arguments `target` and `output` must have the same rank "
#    1161         "(ndim). Received: "
#    1162         f"target.shape={target.shape}, output.shape={output.shape}"
#    1163     )
#    1164 for e1, e2 in zip(target.shape, output.shape):
#    1165     if e1 is not None and e2 is not None and e1 != e2:
#
# ValueError: Arguments `target` and `output` must have the same rank (ndim). Received: target.shape=(32, 10), output.shape=(32, 4, 4, 10)
