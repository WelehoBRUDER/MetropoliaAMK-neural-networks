# %% [markdown]
# # Hand classifier
# This model identifies the number of extended fingers based on a clear image of a human hand.

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"

import keras
from keras import layers

import numpy as np
import matplotlib.pyplot as plt

from keras import backend as K
print(K.backend())
# Out:
# 2026-04-10 11:33:44.664915: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# tensorflow

# %%
from sklearn.model_selection import train_test_split
batch_size_n = 4
img_size = (224, 224)

train_dataset, validation_dataset = keras.utils.image_dataset_from_directory(
    'images/train',
    batch_size=batch_size_n, 
    image_size=img_size,
    crop_to_aspect_ratio=True,
    label_mode='categorical',
    validation_split=0.1125, # ensures validation and test sets are equal size
    subset='both',
    seed=123)

test_dataset = keras.utils.image_dataset_from_directory(
    'images/test',
    batch_size=batch_size_n, 
    image_size=img_size,
    crop_to_aspect_ratio=True,
    label_mode='categorical')
# Out:
# Found 270 files belonging to 5 classes.
# Using 240 files for training.
# Using 30 files for validation.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775810030.370752   60288 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1767 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 30 files belonging to 5 classes.

# %%
x_train = np.concatenate([x for x, y in train_dataset], axis=0)
y_train = np.concatenate([y for x, y in train_dataset], axis=0)
x_val = np.concatenate([x for x, y in validation_dataset], axis=0)
y_val = np.concatenate([y for x, y in validation_dataset], axis=0)
x_test = np.concatenate([x for x, y in test_dataset], axis=0)
y_test = np.concatenate([y for x, y in test_dataset], axis=0)
# Out:
# 2026-04-10 11:37:24.612054: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 2026-04-10 11:37:24.780012: I tensorflow/core/framework/local_rendezvous.cc:407] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence

# %%
print(x_train.shape)
print(y_train.shape)
# Out:
# (240, 224, 224, 3)
# (240, 5)

# %%
from keras import Sequential
from keras import layers
num_classes = 5

model = Sequential([
    layers.Input(shape=(224, 224, 3)),
    layers.Conv2D(32, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.Conv2D(64, kernel_size=(3, 3), activation='relu'),
    layers.MaxPooling2D(pool_size=(2, 2)),
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.5),
    layers.Dense(num_classes, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(x_train, y_train, batch_size=4, epochs=100, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.1917 - loss: 12.5200 - val_accuracy: 0.1667 - val_loss: 1.6263
# Epoch 2/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1875 - loss: 1.6290 - val_accuracy: 0.2333 - val_loss: 1.6062
# Epoch 3/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2250 - loss: 1.6081 - val_accuracy: 0.1667 - val_loss: 1.6064
# Epoch 4/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2000 - loss: 1.6084 - val_accuracy: 0.1000 - val_loss: 1.6071
# Epoch 5/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2042 - loss: 1.6098 - val_accuracy: 0.1333 - val_loss: 1.6062
# Epoch 6/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2000 - loss: 1.6092 - val_accuracy: 0.1333 - val_loss: 1.6070
# Epoch 7/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1875 - loss: 1.6074 - val_accuracy: 0.1000 - val_loss: 1.6096
# Epoch 8/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2250 - loss: 1.6450 - val_accuracy: 0.1667 - val_loss: 1.6081
# Epoch 9/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2167 - loss: 1.6058 - val_accuracy: 0.2667 - val_loss: 1.6110
# Epoch 10/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2292 - loss: 1.6062 - val_accuracy: 0.2000 - val_loss: 1.6092
# Epoch 11/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2375 - loss: 1.6020 - val_accuracy: 0.1667 - val_loss: 1.6141
# Epoch 12/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1958 - loss: 1.5998 - val_accuracy: 0.1667 - val_loss: 1.6110
# Epoch 13/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2000 - loss: 1.6075 - val_accuracy: 0.2333 - val_loss: 1.6119
# Epoch 14/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.1958 - loss: 1.6154 - val_accuracy: 0.2333 - val_loss: 1.6123
# Epoch 15/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.2042 - loss: 1.6041 - val_accuracy: 0.2333 - val_loss: 1.6117
# Epoch 16/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2250 - loss: 1.6045 - val_accuracy: 0.2000 - val_loss: 1.6134
# Epoch 17/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1958 - loss: 1.5968 - val_accuracy: 0.2333 - val_loss: 1.6181
# Epoch 18/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2250 - loss: 1.5948 - val_accuracy: 0.2333 - val_loss: 1.6124
# Epoch 19/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2125 - loss: 1.5895 - val_accuracy: 0.2333 - val_loss: 1.6278
# Epoch 20/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2333 - loss: 1.6022 - val_accuracy: 0.2333 - val_loss: 1.6080
# Epoch 21/100
# 60/60 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.2375 - loss: 1.