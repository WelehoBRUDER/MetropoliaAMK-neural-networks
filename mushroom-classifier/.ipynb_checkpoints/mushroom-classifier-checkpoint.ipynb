# %% [markdown]
# # Mushroom Classifier
# This model's goal is to classify images of mushrooms and determine whether they are poisonous or safe.
# The model was trained with an AMD GPU, which caused a fair amount of issues and forced some architecture changes.

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

import keras
from keras import layers

import numpy as np
import matplotlib.pyplot as plt

from keras import backend as K
import tensorflow as tf

# Verification block
print(f"Keras version: {keras.__version__}")
print(f"TensorFlow version: {tf.__version__}")

# This will list your DirectML adapters (GPU:0 and GPU:1)
gpus = tf.config.list_physical_devices('GPU')
print(f"GPUs Detected: {gpus}")
# Out:
# C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Keras version: 2.10.0
# TensorFlow version: 2.10.0
# GPUs Detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# Performing data augmentation while the Jupyter server was running always crashed the kernel during training phase.
# To fix this, the entire dataset is augmented at once and saved as a new dataset.
# This means that the images are already augmented when loaded as a dataset.

# %%
from sklearn.model_selection import train_test_split
batch_size_n = 64
img_size = (224, 224)

# Load images
dataset = keras.utils.image_dataset_from_directory(
    '../datasets/mushroom_augmented',
    batch_size=batch_size_n, 
    image_size=img_size,
    crop_to_aspect_ratio=True,
    labels='inferred',
    label_mode='categorical',
    shuffle=True,
    seed=123)

num_classes = len(dataset.class_names)
# Out:
# Found 17461 files belonging to 9 classes.

# %% [markdown]
# The total dataset is now much larger than the original, because of the preprocessed images.

# %%
# Split dataset into validation and training
dataset_size = len(dataset)
train_size = int(0.7 * dataset_size)
val_size = int(0.15 * dataset_size)

train_dataset = dataset.take(train_size)
val_dataset = dataset.skip(train_size).take(val_size)
test_dataset = dataset.skip(train_size + val_size)

# %%
# Prefetch datasets to improve performance
import tensorflow as tf
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.cache().prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.cache().prefetch(buffer_size=AUTOTUNE)

# %%
from keras import Sequential
from keras import layers
from keras.optimizers import Adam

# %% [markdown]
# Because of how older versions of tensorflow work, data augmentation MUST be done outside of the training.
# CPU bottleneck kills performance, making training take ~20x longer.

# %%
model = Sequential([
    layers.Input(shape=(224, 224, 3)),
    layers.Rescaling(1./255),
    
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D(),

    layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    layers.GlobalAveragePooling2D(), # Or layers.Flatten() for more parameters
    
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 222, 222, 64)      1792
#
#  max_pooling2d (MaxPooling2D  (None, 111, 111, 64)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 109, 109, 128)     73856
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 128)      0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 52, 52, 256)       295168
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 173056)            0
#
#  dense (Dense)               (None, 256)               44302592
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 44,675,721
# Trainable params: 44,675,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate = 0.0001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping

history = model.fit(
    train_dataset,
    batch_size=batch_size_n,
    epochs=64,
    validation_data=val_dataset,
    callbacks=[
        EarlyStopping(patience=5, restore_best_weights=True)
    ]
)
# Out:
# Epoch 1/64
# 95/95 [==============================] - 18s 172ms/step - loss: 2.0428 - accuracy: 0.2250 - val_loss: 1.8846 - val_accuracy: 0.3105
# Epoch 2/64
# 95/95 [==============================] - 10s 104ms/step - loss: 1.8542 - accuracy: 0.3153 - val_loss: 1.7295 - val_accuracy: 0.3914
# Epoch 3/64
# 95/95 [==============================] - 10s 105ms/step - loss: 1.7332 - accuracy: 0.3702 - val_loss: 1.6551 - val_accuracy: 0.4293
# Epoch 4/64
# 95/95 [==============================] - 10s 107ms/step - loss: 1.6338 - accuracy: 0.4150 - val_loss: 1.5872 - val_accuracy: 0.4516
# Epoch 5/64
# 95/95 [==============================] - 10s 107ms/step - loss: 1.5349 - accuracy: 0.4587 - val_loss: 1.5607 - val_accuracy: 0.4609
# Epoch 6/64
# 95/95 [==============================] - 10s 106ms/step - loss: 1.4251 - accuracy: 0.4967 - val_loss: 1.4902 - val_accuracy: 0.4930
# Epoch 7/64
# 95/95 [==============================] - 10s 107ms/step - loss: 1.3177 - accuracy: 0.5384 - val_loss: 1.4663 - val_accuracy: 0.4957
# Epoch 8/64
# 95/95 [==============================] - 10s 108ms/step - loss: 1.2153 - accuracy: 0.5755 - val_loss: 1.4287 - val_accuracy: 0.5234
# Epoch 9/64
# 95/95 [==============================] - 10s 107ms/step - loss: 1.1078 - accuracy: 0.6146 - val_loss: 1.3979 - val_accuracy: 0.5324
# Epoch 10/64
# 95/95 [==============================] - 10s 107ms/step - loss: 1.0057 - accuracy: 0.6493 - val_loss: 1.3765 - val_accuracy: 0.5508
# Epoch 11/64
# 95/95 [==============================] - 10s 107ms/step - loss: 0.9072 - accuracy: 0.6854 - val_loss: 1.3929 - val_accuracy: 0.5477
# Epoch 12/64
# 95/95 [==============================] - 10s 107ms/step - loss: 0.8255 - accuracy: 0.7130 - val_loss: 1.4022 - val_accuracy: 0.5457
# Epoch 13/64
# 95/95 [==============================] - 10s 107ms/step - loss: 0.7478 - accuracy: 0.7451 - val_loss: 1.3740 - val_accuracy: 0.5652
# Epoch 14/64
# 95/95 [==============================] - 10s 106ms/step - loss: 0.6820 - accuracy: 0.7613 - val_loss: 1.3842 - val_accuracy: 0.5605
# Epoch 15/64
# 95/95 [==============================] - 10s 106ms/step - loss: 0.6190 - accuracy: 0.7897 - val_loss: 1.3996 - val_accuracy: 0.5605
# Epoch 16/64
# 95/95 [==============================] - 10s 106ms/step - loss: 0.5897 - accuracy: 0.8002 - val_loss: 1.4105 - val_accuracy: 0.5754
# Epoch 17/64
# 95/95 [==============================] - 10s 107ms/step - loss: 0.5214 - accuracy: 0.8237 - val_loss: 1.4465 - val_accuracy: 0.5813
# Epoch 18/64
# 95/95 [==============================] - 10s 107ms/step - loss: 0.4698 - accuracy: 0.8385 - val_loss: 1.4577 - val_accuracy: 0.5777

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
loss, acc = model.evaluate(test_dataset, verbose=0)
print(f"The model's test accuracy is {acc}")
# Out:
# The model's test accuracy is 0.47391465306282043
