# %% [markdown]
# # Mushroom Classifier
# This model's goal is to classify images of mushrooms and determine whether they are poisonous or safe.
# The model was trained with an AMD GPU, which caused a fair amount of issues and forced some architecture changes.

# %%
import os
os.environ["KERAS_BACKEND"] = "tensorflow"
os.environ["CUDA_VISIBLE_DEVICES"] = "1"

import keras
from keras import layers

import numpy as np
import matplotlib.pyplot as plt

from keras import backend as K
import tensorflow as tf

# Verification block
print(f"Keras version: {keras.__version__}")
print(f"TensorFlow version: {tf.__version__}")

# This will list your DirectML adapters (GPU:0 and GPU:1)
gpus = tf.config.list_physical_devices('GPU')
print(f"GPUs Detected: {gpus}")
# Out:
# C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Keras version: 2.10.0
# TensorFlow version: 2.10.0
# GPUs Detected: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %% [markdown]
# Performing data augmentation while the Jupyter server was running always crashed the kernel during training phase.
# To fix this, the entire dataset is augmented at once and saved as a new dataset.
# This means that the images are already augmented when loaded as a dataset.

# %%
from sklearn.model_selection import train_test_split
batch_size_n = 64
img_size = (224, 224)

# Load images
train_dataset = keras.utils.image_dataset_from_directory(
    '../datasets/mushroom_augmented/train',
    batch_size=batch_size_n, 
    image_size=img_size,
    crop_to_aspect_ratio=True,
    labels='inferred',
    label_mode='int',
    shuffle=True,
    seed=123)

test_dataset = keras.utils.image_dataset_from_directory(
    '../datasets/mushroom_augmented/test',
    batch_size=batch_size_n, 
    image_size=img_size,
    crop_to_aspect_ratio=True,
    labels='inferred',
    label_mode='int',
    shuffle=True,
    seed=123)

val_dataset = keras.utils.image_dataset_from_directory(
    '../datasets/mushroom_augmented/val',
    batch_size=batch_size_n, 
    image_size=img_size,
    crop_to_aspect_ratio=True,
    labels='inferred',
    label_mode='int',
    shuffle=True,
    seed=123)

num_classes = len(train_dataset.class_names)
# Out:
# Found 17417 files belonging to 9 classes.
# Found 1015 files belonging to 9 classes.
# Found 1002 files belonging to 9 classes.

# %% [markdown]
# The total dataset is now much larger than the original, because of the preprocessed images.

# %%
# Split dataset into validation and training
#dataset_size = len(dataset)
#train_size = int(0.7 * dataset_size)
#val_size = int(0.15 * dataset_size)

#train_dataset = dataset.take(train_size)
#val_dataset = dataset.skip(train_size).take(val_size)
#test_dataset = dataset.skip(train_size + val_size)

# %%
# Prefetch datasets to improve performance
import tensorflow as tf
AUTOTUNE = tf.data.AUTOTUNE

train_dataset = train_dataset.cache().prefetch(buffer_size=AUTOTUNE)
val_dataset = val_dataset.cache().prefetch(buffer_size=AUTOTUNE)
test_dataset = test_dataset.cache().prefetch(buffer_size=AUTOTUNE)

# %%
from keras import Sequential
from keras import layers
from keras.optimizers import Adam

# %% [markdown]
# ## CNN model (custom)
# This model is a convolutional network that will be fully trained from the ground up on this dataset.

# %%
model = Sequential([
    layers.Input(shape=(224, 224, 3)),
    layers.Rescaling(1./255),
    
    layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D(),
    
    layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
    layers.MaxPooling2D(),

    layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
    layers.GlobalAveragePooling2D(), # Or layers.Flatten() for more parameters
    
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.3),
    layers.Dense(num_classes, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 224, 224, 3)       0
#
#  conv2d (Conv2D)             (None, 224, 224, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 256)       295168
#
#  global_average_pooling2d (G  (None, 256)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 256)               65792
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 456,521
# Trainable params: 456,521
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate = 0.0001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping

history = model.fit(
    train_dataset,
    batch_size=batch_size_n,
    epochs=64,
    validation_data=val_dataset,
    callbacks=[
        EarlyStopping(patience=5, restore_best_weights=True)
    ]
)
# Out:
# Epoch 1/64
# 273/273 [==============================] - 10s 35ms/step - loss: 2.0552 - accuracy: 0.2176 - val_loss: 1.9876 - val_accuracy: 0.2395
# Epoch 2/64
# 273/273 [==============================] - 8s 30ms/step - loss: 1.9612 - accuracy: 0.2333 - val_loss: 1.9065 - val_accuracy: 0.2834
# Epoch 3/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.8958 - accuracy: 0.2769 - val_loss: 1.8560 - val_accuracy: 0.2994
# Epoch 4/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.8515 - accuracy: 0.3044 - val_loss: 1.8072 - val_accuracy: 0.3084
# Epoch 5/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.8190 - accuracy: 0.3259 - val_loss: 1.7809 - val_accuracy: 0.3413
# Epoch 6/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.7854 - accuracy: 0.3428 - val_loss: 1.7539 - val_accuracy: 0.3433
# Epoch 7/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.7539 - accuracy: 0.3602 - val_loss: 1.7184 - val_accuracy: 0.3643
# Epoch 8/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.7185 - accuracy: 0.3749 - val_loss: 1.6871 - val_accuracy: 0.3743
# Epoch 9/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.6848 - accuracy: 0.3944 - val_loss: 1.6710 - val_accuracy: 0.3792
# Epoch 10/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.6538 - accuracy: 0.4087 - val_loss: 1.6501 - val_accuracy: 0.3992
# Epoch 11/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.6231 - accuracy: 0.4176 - val_loss: 1.6080 - val_accuracy: 0.4162
# Epoch 12/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.5952 - accuracy: 0.4338 - val_loss: 1.5800 - val_accuracy: 0.4222
# Epoch 13/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.5757 - accuracy: 0.4404 - val_loss: 1.5606 - val_accuracy: 0.4301
# Epoch 14/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.5438 - accuracy: 0.4492 - val_loss: 1.5450 - val_accuracy: 0.4431
# Epoch 15/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.5291 - accuracy: 0.4548 - val_loss: 1.5346 - val_accuracy: 0.4391
# Epoch 16/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.5086 - accuracy: 0.4604 - val_loss: 1.5184 - val_accuracy: 0.4441
# Epoch 17/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.4935 - accuracy: 0.4654 - val_loss: 1.5127 - val_accuracy: 0.4481
# Epoch 18/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.4778 - accuracy: 0.4738 - val_loss: 1.4956 - val_accuracy: 0.4571
# Epoch 19/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.4634 - accuracy: 0.4826 - val_loss: 1.4841 - val_accuracy: 0.4641
# Epoch 20/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.4464 - accuracy: 0.4843 - val_loss: 1.4868 - val_accuracy: 0.4731
# Epoch 21/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.4444 - accuracy: 0.4864 - val_loss: 1.4768 - val_accuracy: 0.4731
# Epoch 22/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.4221 - accuracy: 0.4936 - val_loss: 1.4666 - val_accuracy: 0.4760
# Epoch 23/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.4105 - accuracy: 0.4963 - val_loss: 1.4626 - val_accuracy: 0.4760
# Epoch 24/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.4015 - accuracy: 0.5009 - val_loss: 1.4576 - val_accuracy: 0.4820
# Epoch 25/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.3957 - accuracy: 0.5033 - val_loss: 1.4496 - val_accuracy: 0.4900
# Epoch 26/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.3794 - accuracy: 0.5061 - val_loss: 1.4397 - val_accuracy: 0.4930
# Epoch 27/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.3723 - accuracy: 0.5129 - val_loss: 1.4391 - val_accuracy: 0.4970
# Epoch 28/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.3638 - accuracy: 0.5186 - val_loss: 1.4417 - val_accuracy: 0.4910
# Epoch 29/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.3490 - accuracy: 0.5202 - val_loss: 1.4260 - val_accuracy: 0.4990
# Epoch 30/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.3444 - accuracy: 0.5191 - val_loss: 1.4212 - val_accuracy: 0.5020
# Epoch 31/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.3281 - accuracy: 0.5306 - val_loss: 1.4224 - val_accuracy: 0.5080
# Epoch 32/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.3229 - accuracy: 0.5282 - val_loss: 1.4097 - val_accuracy: 0.5170
# Epoch 33/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.3146 - accuracy: 0.5320 - val_loss: 1.4087 - val_accuracy: 0.5120
# Epoch 34/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.3050 - accuracy: 0.5342 - val_loss: 1.4098 - val_accuracy: 0.5200
# Epoch 35/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2975 - accuracy: 0.5376 - val_loss: 1.4002 - val_accuracy: 0.5170
# Epoch 36/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2853 - accuracy: 0.5425 - val_loss: 1.3971 - val_accuracy: 0.5210
# Epoch 37/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2796 - accuracy: 0.5464 - val_loss: 1.3941 - val_accuracy: 0.5220
# Epoch 38/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2730 - accuracy: 0.5492 - val_loss: 1.3980 - val_accuracy: 0.5250
# Epoch 39/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2685 - accuracy: 0.5487 - val_loss: 1.3887 - val_accuracy: 0.5240
# Epoch 40/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2540 - accuracy: 0.5543 - val_loss: 1.3807 - val_accuracy: 0.5289
# Epoch 41/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2479 - accuracy: 0.5580 - val_loss: 1.3738 - val_accuracy: 0.5269
# Epoch 42/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2412 - accuracy: 0.5595 - val_loss: 1.3670 - val_accuracy: 0.5289
# Epoch 43/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2372 - accuracy: 0.5609 - val_loss: 1.3713 - val_accuracy: 0.5429
# Epoch 44/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2272 - accuracy: 0.5630 - val_loss: 1.3728 - val_accuracy: 0.5339
# Epoch 45/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2214 - accuracy: 0.5650 - val_loss: 1.3625 - val_accuracy: 0.5409
# Epoch 46/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2169 - accuracy: 0.5681 - val_loss: 1.3709 - val_accuracy: 0.5319
# Epoch 47/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.2051 - accuracy: 0.5727 - val_loss: 1.3601 - val_accuracy: 0.5429
# Epoch 48/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1963 - accuracy: 0.5753 - val_loss: 1.3547 - val_accuracy: 0.5379
# Epoch 49/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1915 - accuracy: 0.5770 - val_loss: 1.3491 - val_accuracy: 0.5549
# Epoch 50/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1851 - accuracy: 0.5758 - val_loss: 1.3507 - val_accuracy: 0.5459
# Epoch 51/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1768 - accuracy: 0.5767 - val_loss: 1.3375 - val_accuracy: 0.5579
# Epoch 52/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1752 - accuracy: 0.5766 - val_loss: 1.3588 - val_accuracy: 0.5389
# Epoch 53/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1692 - accuracy: 0.5831 - val_loss: 1.3409 - val_accuracy: 0.5649
# Epoch 54/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1527 - accuracy: 0.5880 - val_loss: 1.3419 - val_accuracy: 0.5499
# Epoch 55/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1502 - accuracy: 0.5902 - val_loss: 1.3452 - val_accuracy: 0.5519
# Epoch 56/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1449 - accuracy: 0.5951 - val_loss: 1.3366 - val_accuracy: 0.5629
# Epoch 57/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1392 - accuracy: 0.5916 - val_loss: 1.3411 - val_accuracy: 0.5539
# Epoch 58/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1329 - accuracy: 0.5998 - val_loss: 1.3370 - val_accuracy: 0.5449
# Epoch 59/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1263 - accuracy: 0.5967 - val_loss: 1.3262 - val_accuracy: 0.5629
# Epoch 60/64
# 273/273 [==============================] - 8s 28ms/step - loss: 1.1203 - accuracy: 0.6002 - val_loss: 1.3287 - val_accuracy: 0.5589
# Epoch 61/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1148 - accuracy: 0.6008 - val_loss: 1.3351 - val_accuracy: 0.5609
# Epoch 62/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1122 - accuracy: 0.6018 - val_loss: 1.3316 - val_accuracy: 0.5669
# Epoch 63/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.1026 - accuracy: 0.6078 - val_loss: 1.3258 - val_accuracy: 0.5649
# Epoch 64/64
# 273/273 [==============================] - 8s 29ms/step - loss: 1.0938 - accuracy: 0.6112 - val_loss: 1.3272 - val_accuracy: 0.5609

# %%
acc = history.history["accuracy"]
val_acc = history.history["val_accuracy"]
loss = history.history["loss"]
val_loss = history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_dataset)
val_loss, val_acc = model.evaluate(val_dataset)
print("Test accuracy:", test_acc)
print("Validation accuracy:", val_acc)
# Out:
# 16/16 [==============================] - 1s 17ms/step - loss: 1.3018 - accuracy: 0.5468
# 16/16 [==============================] - 0s 9ms/step - loss: 1.3272 - accuracy: 0.5609
# Test accuracy: 0.546798050403595
# Validation accuracy: 0.5608782172203064

# %% [markdown]
# The baseline for the current model is ~57%, with slight variations on each training run.
# Mushrooms are very complex structures, which means that this model needs to learn to sort through a lot of parameters.
# Pretrained models should be better at this task. The next cells compare the performance of EfficientNet and MobileNetV2.

# %% [markdown]
# ## MobileNetV2 Model

# %%
import tensorflow as tf
from keras.applications import MobileNetV2
from keras import Sequential
from keras import layers
from keras.optimizers import Adam

conv_base = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

conv_base.trainable = False

# %%
from keras.optimizers import Adam
from keras.applications.mobilenet_v2 import preprocess_input

inputs = layers.Input(shape=(224, 224,3))
x = preprocess_input(inputs)
x = conv_base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_5 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv_1 (TFOpLamb  (None, 224, 224, 3)      0
#  da)
#
#  tf.math.subtract_1 (TFOpLam  (None, 224, 224, 3)      0
#  bda)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_2   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dense_4 (Dense)             (None, 256)               327936
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 2,588,233
# Trainable params: 330,249
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]

mobilenet_history = model.fit(
    train_dataset,
    epochs=64,
    validation_data=val_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 9
#       1 callbacks = [
#       2     keras.callbacks.ModelCheckpoint(
#       3         filepath="feature_extraction.keras",
#    (...)
#       6     )
#       7 ]
# ----> 9 mobilenet_history = model.fit(
#      10     train_dataset,
#      11     epochs=64,
#      12     validation_data=val_dataset,
#      13     callbacks=callbacks,
#      14 )
#
# File ~\anaconda3\envs\tf_directml\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Temp\__autograph_generated_file77tw10jl.py:15, in outer_factory.<locals>.inner_factory.<locals>.tf__train_function(iterator)
#      13 try:
#      14     do_return = True
# ---> 15     retval_ = ag__.converted_call(ag__.ld(step_function), (ag__.ld(self), ag__.ld(iterator)), None, fscope)
#      16 except:
#      17     do_return = False
#
# ValueError: in user code:
#
#     File "C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\keras\engine\training.py", line 1160, in train_function  *
#         return step_function(self, iterator)
#     File "C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\keras\engine\training.py", line 1146, in step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     File "C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\keras\engine\training.py", line 1135, in run_step  **
#         outputs = model.train_step(data)
#     File "C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\keras\engine\training.py", line 994, in train_step
#         loss = self.compute_loss(x, y, y_pred, sample_weight)
#     File "C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\keras\engine\training.py", line 1052, in compute_loss
#         return self.compiled_loss(
#     File "C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\keras\engine\compile_utils.py", line 265, in __call__
#         loss_value = loss_obj(y_t, y_p, sample_weight=sw)
#     File "C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\keras\losses.py", line 152, in __call__
#         losses = call_fn(y_true, y_pred)
#     File "C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\keras\losses.py", line 272, in call  **
#         return ag_fn(y_true, y_pred, **self._fn_kwargs)
#     File "C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\keras\losses.py", line 1990, in categorical_crossentropy
#         return backend.categorical_crossentropy(
#     File "C:\Users\Omistaja\anaconda3\envs\tf_directml\lib\site-packages\keras\backend.py", line 5529, in categorical_crossentropy
#         target.shape.assert_is_compatible_with(output.shape)
#
#     ValueError: Shapes (None, 1) and (None, 9) are incompatible

# %%
acc = mobilenet_history.history["accuracy"]
val_acc = mobilenet_history.history["val_accuracy"]
loss = mobilenet_history.history["loss"]
val_loss = mobilenet_history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_dataset)
val_loss, val_acc = model.evaluate(val_dataset)
print("Test accuracy:", test_acc)
print("Validation accuracy:", val_acc)

# %% [markdown]
# ## MobileNetV2 Model (finetuned)

# %%
import tensorflow as tf
from keras.applications import MobileNetV2

conv_base = MobileNetV2(
    weights='imagenet',
    include_top=False,
    input_shape=(224, 224, 3)
)

# freeze all training
conv_base.trainable = False

# %%
from keras.optimizers import Adam
inputs = layers.Input(shape=(224, 224,3))
x = preprocess_input(inputs)
x = conv_base(x, training=False)
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(num_classes, activation='softmax')(x)
model = keras.Model(inputs, outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.math.truediv (TFOpLambda  (None, 224, 224, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 224, 224, 3)      0
#  a)
#
#  mobilenetv2_1.00_224 (Funct  (None, 7, 7, 1280)       2257984
#  ional)
#
#  global_average_pooling2d_1   (None, 1280)             0
#  (GlobalAveragePooling2D)
#
#  dense_2 (Dense)             (None, 256)               327936
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_3 (Dense)             (None, 9)                 2313
#
# =================================================================
# Total params: 2,588,233
# Trainable params: 330,249
# Non-trainable params: 2,257,984
# _________________________________________________________________

# %%
model.compile(optimizer=Adam(learning_rate=1e-3), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss",
    )
]

mobilenet_history = model.fit(
    train_dataset,
    batch_size=batch_size_n,
    epochs=5,
    validation_data=val_dataset,
    callbacks=callbacks,
)
# Out:
# Epoch 1/5
# 273/273 [==============================] - 8s 25ms/step - loss: 1.0082 - accuracy: 0.6461 - val_loss: 0.7539 - val_accuracy: 0.7375
# Epoch 2/5
# 273/273 [==============================] - 6s 24ms/step - loss: 0.6032 - accuracy: 0.7872 - val_loss: 0.6987 - val_accuracy: 0.7685
# Epoch 3/5
# 273/273 [==============================] - 6s 24ms/step - loss: 0.4593 - accuracy: 0.8383 - val_loss: 0.6692 - val_accuracy: 0.7625
# Epoch 4/5
# 273/273 [==============================] - 6s 24ms/step - loss: 0.3637 - accuracy: 0.8728 - val_loss: 0.6655 - val_accuracy: 0.7745
# Epoch 5/5
# 273/273 [==============================] - 6s 24ms/step - loss: 0.2925 - accuracy: 0.8971 - val_loss: 0.6640 - val_accuracy: 0.7695

# %%
conv_base.trainable = True

for layer in conv_base.layers[:-4]:
    layer.trainable = False
    
for layer in conv_base.layers[-4:]:
    layer.trainable = True

model.compile(optimizer=Adam(learning_rate=1e-5), loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping

finetuned_history = model.fit(
    train_dataset,
    epochs=64,
    validation_data=val_dataset,
    callbacks=[
        EarlyStopping(patience=3, restore_best_weights=True)
    ]
)
# Out:
# Epoch 1/64
# 273/273 [==============================] - 9s 27ms/step - loss: 0.2266 - accuracy: 0.9244 - val_loss: 0.6222 - val_accuracy: 0.8044
# Epoch 2/64
# 273/273 [==============================] - 7s 25ms/step - loss: 0.1909 - accuracy: 0.9385 - val_loss: 0.6179 - val_accuracy: 0.8054
# Epoch 3/64
# 273/273 [==============================] - 7s 25ms/step - loss: 0.1727 - accuracy: 0.9437 - val_loss: 0.6172 - val_accuracy: 0.8014
# Epoch 4/64
# 273/273 [==============================] - 7s 25ms/step - loss: 0.1587 - accuracy: 0.9510 - val_loss: 0.6142 - val_accuracy: 0.8044
# Epoch 5/64
# 273/273 [==============================] - 7s 25ms/step - loss: 0.1464 - accuracy: 0.9542 - val_loss: 0.6168 - val_accuracy: 0.8054
# Epoch 6/64
# 273/273 [==============================] - 7s 25ms/step - loss: 0.1389 - accuracy: 0.9579 - val_loss: 0.6105 - val_accuracy: 0.8084
# Epoch 7/64
# 273/273 [==============================] - 7s 25ms/step - loss: 0.1273 - accuracy: 0.9611 - val_loss: 0.6116 - val_accuracy: 0.8104
# Epoch 8/64
# 273/273 [==============================] - 7s 25ms/step - loss: 0.1205 - accuracy: 0.9647 - val_loss: 0.6145 - val_accuracy: 0.8114
# Epoch 9/64
# 273/273 [==============================] - 7s 25ms/step - loss: 0.1126 - accuracy: 0.9674 - val_loss: 0.6144 - val_accuracy: 0.8084

# %%
acc = finetuned_history.history["accuracy"]
val_acc = finetuned_history.history["val_accuracy"]
loss = finetuned_history.history["loss"]
val_loss = finetuned_history.history["val_loss"]
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, "r--", label="Training accuracy")
plt.plot(epochs, val_acc, "b", label="Validation accuracy")
plt.title("Training and validation accuracy")
plt.legend()
plt.figure()
plt.plot(epochs, loss, "r--", label="Training loss")
plt.plot(epochs, val_loss, "b", label="Validation loss")
plt.title("Training and validation loss")
plt.legend()
plt.show()

# %%
test_loss, test_acc = model.evaluate(test_dataset)
val_loss, val_acc = model.evaluate(val_dataset)
print("Test accuracy:", test_acc)
print("Validation accuracy:", val_acc)
# Out:
# 16/16 [==============================] - 0s 22ms/step - loss: 0.6636 - accuracy: 0.7970
# 16/16 [==============================] - 0s 21ms/step - loss: 0.6105 - accuracy: 0.8084
# Test accuracy: 0.7970443367958069
# Validation accuracy: 0.8083832263946533

# %% [markdown]
# ## EfficientNet Model
